# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# This Datasets contain the total 7725 rows and 25 columns

# %%
df.head(10)
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
# 5      6.0  30-06-2013          31.9          23.5    52.437126    85.307251
# 6      7.0  30-06-2013          31.4          24.4    56.287189    81.019760
# 7      8.0  30-06-2013          32.1          23.6    52.326218    78.004539
# 8      9.0  30-06-2013          31.4          22.0    55.338791    80.784607
# 9     10.0  30-06-2013          31.6          20.5    56.651203    86.849632
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# ...

# %%
df.tail(10)
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7742     18.0  30-08-2017          23.3          18.2    30.259682
# 7743     19.0  30-08-2017          22.6          15.0    25.536045
# 7744     20.0  30-08-2017          22.7          15.9    38.216373
# 7745     21.0  30-08-2017          23.1          17.8    24.688997
# 7746     22.0  30-08-2017          22.5          17.4    30.094858
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7742    86.565193         26.474403         17.289157   6.522731   94.203783
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# above datasets contains the total float type columns and one is objective columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imp=SimpleImputer(strategy="mean")
df['Present_Tmax']=imp.fit_transform(df[['Present_Tmax']])

# %%
imp=SimpleImputer(strategy="mean")
df['Present_Tmin']=imp.fit_transform(df[['Present_Tmin']])
df['LDAPS_RHmin']=imp.fit_transform(df[['LDAPS_RHmin']])
df['LDAPS_RHmax']=imp.fit_transform(df[['LDAPS_RHmax']])
df['LDAPS_Tmax_lapse']=imp.fit_transform(df[['LDAPS_Tmax_lapse']])
df['LDAPS_Tmin_lapse']=imp.fit_transform(df[['LDAPS_Tmin_lapse']])
df['LDAPS_WS']=imp.fit_transform(df[['LDAPS_WS']])
df['LDAPS_LH']=imp.fit_transform(df[['LDAPS_LH']])
df['LDAPS_CC1']=imp.fit_transform(df[['LDAPS_CC1']])
df['LDAPS_CC2']=imp.fit_transform(df[['LDAPS_CC2']])
df['LDAPS_CC3']=imp.fit_transform(df[['LDAPS_CC3']])
df['LDAPS_CC4']=imp.fit_transform(df[['LDAPS_CC4']])
df['LDAPS_PPT1']=imp.fit_transform(df[['LDAPS_PPT1']])
df['LDAPS_PPT2']=imp.fit_transform(df[['LDAPS_PPT2']])
df['LDAPS_PPT3']=imp.fit_transform(df[['LDAPS_PPT3']])
df['LDAPS_PPT3']=imp.fit_transform(df[['LDAPS_PPT3']])
df['LDAPS_PPT4']=imp.fit_transform(df[['LDAPS_PPT4']])
df['Next_Tmax']=imp.fit_transform(df[['Next_Tmax']])
df['Next_Tmin']=imp.fit_transform(df[['Next_Tmin']])
df['station']=imp.fit_transform(df[['station']])

# %%
imp=SimpleImputer(strategy="most_frequent")
df['Date']=imp.fit_transform(df[['Date']])

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7752.000000   7752.000000   7752.000000  7752.000000  7752.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.210637      2.956557      2.403036    14.596973     7.157124
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    46.046162    84.316923
# 50%      13.000000     29.900000     23.400000    55.313244    89.699505
# 75%      19.000000     32.000000     24.900000    67.038254    93.704500
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7752.000000       7752.000000  7752.000000  7752.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.932898          2.333973     2.173245    33.567001
# ...

# %% [markdown]
# from the abopve description we can see oulier present some columns like station,present tmax,LDAPs rhmax,LDAPS rhmin.
# positive skewness is also present in some columns

# %%
df.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.262942
# Present_Tmin       -0.365875
# LDAPS_RHmin         0.298765
# LDAPS_RHmax        -0.850870
# LDAPS_Tmax_lapse   -0.226775
# LDAPS_Tmin_lapse   -0.578943
# LDAPS_WS            1.571581
# LDAPS_LH            0.670491
# LDAPS_CC1           0.457231
# LDAPS_CC2           0.470060
# LDAPS_CC3           0.637630
# LDAPS_CC4           0.663251
# LDAPS_PPT1          5.367675
# LDAPS_PPT2          5.747360
# LDAPS_PPT3          6.425829
# LDAPS_PPT4          6.792379
# lat                 0.087062
# lon                -0.285213
# DEM                 1.723257
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.339607
# Next_Tmin          -0.403743
# dtype: float64

# %%
df.hist(figsize=(30,30),layout=(6,6),grid=True,bins=30)
# Out:
# array([[<Axes: title={'center': 'station'}>,
#         <Axes: title={'center': 'Present_Tmax'}>,
#         <Axes: title={'center': 'Present_Tmin'}>,
#         <Axes: title={'center': 'LDAPS_RHmin'}>,
#         <Axes: title={'center': 'LDAPS_RHmax'}>,
#         <Axes: title={'center': 'LDAPS_Tmax_lapse'}>],
#        [<Axes: title={'center': 'LDAPS_Tmin_lapse'}>,
#         <Axes: title={'center': 'LDAPS_WS'}>,
#         <Axes: title={'center': 'LDAPS_LH'}>,
#         <Axes: title={'center': 'LDAPS_CC1'}>,
#         <Axes: title={'center': 'LDAPS_CC2'}>,
#         <Axes: title={'center': 'LDAPS_CC3'}>],
#        [<Axes: title={'center': 'LDAPS_CC4'}>,
#         <Axes: title={'center': 'LDAPS_PPT1'}>,
#         <Axes: title={'center': 'LDAPS_PPT2'}>,
#         <Axes: title={'center': 'LDAPS_PPT3'}>,
#         <Axes: title={'center': 'LDAPS_PPT4'}>,
#         <Axes: title={'center': 'lat'}>],
#        [<Axes: title={'center': 'lon'}>, <Axes: title={'center': 'DEM'}>,
# ...

# %% [markdown]
# The above graph show that present tmax,present tmin and Ldamps graph distributed normally and in rest of the columns skewness is present.

# %%
#removing the skewness
df['LDAPS_WS']=np.cbrt(df['LDAPS_WS'])
df['LDAPS_PPT1']=np.cbrt(df['LDAPS_PPT1'])
df['LDAPS_PPT2']=np.cbrt(df['LDAPS_PPT2'])
df['LDAPS_PPT3']=np.cbrt(df['LDAPS_PPT3'])
df['LDAPS_PPT4']=np.cbrt(df['LDAPS_PPT4'])
df['DEM']=np.cbrt(df['DEM'])
df['Slope ']=np.cbrt(df['Slope'])

# %%
df.skew()
# Out:
# station             0.000000
# Present_Tmax       -0.264137
# Present_Tmin       -0.367538
# LDAPS_RHmin         0.300220
# LDAPS_RHmax        -0.855015
# LDAPS_Tmax_lapse   -0.227880
# LDAPS_Tmin_lapse   -0.581763
# LDAPS_WS            0.884657
# LDAPS_LH            0.673757
# LDAPS_CC1           0.459458
# LDAPS_CC2           0.472350
# LDAPS_CC3           0.640735
# LDAPS_CC4           0.666482
# LDAPS_PPT1          1.922841
# LDAPS_PPT2          2.223126
# LDAPS_PPT3          2.523911
# LDAPS_PPT4          2.792122
# lat                 0.087062
# lon                -0.285213
# DEM                 0.919779
# Slope               1.563020
# Solar radiation    -0.511210
# Next_Tmax          -0.340200
# Next_Tmin          -0.404447
# Slope               0.614110
# dtype: float64

# %%
sns.scatterplot(data=df, x="Present_Tmin", y="Next_Tmax")
# Out:
# <Axes: xlabel='Present_Tmin', ylabel='Next_Tmax'>

# %%
sns.scatterplot(x='Present_Tmax',y='Next_Tmax',data=df)
# Out:
# <Axes: xlabel='Present_Tmax', ylabel='Next_Tmax'>

# %%
sns.scatterplot(x='LDAPS_RHmin',y='Next_Tmin',data=df)
# Out:
# <Axes: xlabel='LDAPS_RHmin', ylabel='Next_Tmin'>

# %%
sns.scatterplot(x='LDAPS_RHmax',y='Next_Tmax',data=df)
# Out:
# <Axes: xlabel='LDAPS_RHmax', ylabel='Next_Tmax'>

# %%
sns.scatterplot(x='LDAPS_Tmax_lapse',y='Next_Tmax',data=df)
# Out:
# <Axes: xlabel='LDAPS_Tmax_lapse', ylabel='Next_Tmax'>

# %%
sns.scatterplot(x='LDAPS_Tmax_lapse',y='Next_Tmin',data=df)
# Out:
# <Axes: xlabel='LDAPS_Tmax_lapse', ylabel='Next_Tmin'>

# %%
sns.scatterplot(x='LDAPS_CC1',y='Next_Tmax',data=df)
# Out:
# <Axes: xlabel='LDAPS_CC1', ylabel='Next_Tmax'>

# %% [markdown]
# # encoding the categorical column

# %%
 from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df['Date']=le.fit_transform(df['Date'])

# %%
df.plot(kind='box',subplots=True,layout=(6,6),figsize=(15,20))
# Out:
# station                 Axes(0.125,0.77;0.110714x0.11)
# Date                 Axes(0.257857,0.77;0.110714x0.11)
# Present_Tmax         Axes(0.390714,0.77;0.110714x0.11)
# Present_Tmin         Axes(0.523571,0.77;0.110714x0.11)
# LDAPS_RHmin          Axes(0.656429,0.77;0.110714x0.11)
# LDAPS_RHmax          Axes(0.789286,0.77;0.110714x0.11)
# LDAPS_Tmax_lapse       Axes(0.125,0.638;0.110714x0.11)
# LDAPS_Tmin_lapse    Axes(0.257857,0.638;0.110714x0.11)
# LDAPS_WS            Axes(0.390714,0.638;0.110714x0.11)
# LDAPS_LH            Axes(0.523571,0.638;0.110714x0.11)
# LDAPS_CC1           Axes(0.656429,0.638;0.110714x0.11)
# LDAPS_CC2           Axes(0.789286,0.638;0.110714x0.11)
# LDAPS_CC3              Axes(0.125,0.506;0.110714x0.11)
# LDAPS_CC4           Axes(0.257857,0.506;0.110714x0.11)
# LDAPS_PPT1          Axes(0.390714,0.506;0.110714x0.11)
# LDAPS_PPT2          Axes(0.523571,0.506;0.110714x0.11)
# LDAPS_PPT3          Axes(0.656429,0.506;0.110714x0.11)
# ...

# %%
from scipy.stats import zscore

# %%
feature=df[['Present_Tmax','Present_Tmin','LDAPS_RHmax','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4',]]

# %%
z=np.abs(zscore(feature))

# %%
z
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmax  LDAPS_PPT1  LDAPS_PPT2  \
# 0              NaN           NaN          NaN         NaN         NaN
# 1              NaN           NaN          NaN         NaN         NaN
# 2              NaN           NaN          NaN         NaN         NaN
# 3              NaN           NaN          NaN         NaN         NaN
# 4              NaN           NaN          NaN         NaN         NaN
# ...            ...           ...          ...         ...         ...
# 7747           NaN           NaN          NaN         NaN         NaN
# 7748           NaN           NaN          NaN         NaN         NaN
# 7749           NaN           NaN          NaN         NaN         NaN
# 7750           NaN           NaN          NaN         NaN         NaN
# 7751           NaN           NaN          NaN         NaN         NaN
#
#       LDAPS_PPT3  LDAPS_PPT4
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# ...

# %%
cor=df.corr()
cor
# Out:
#                        station          Date  Present_Tmax  Present_Tmin  \
# station           1.000000e+00  2.503011e-17      0.112655      0.131646
# Date              2.503011e-17  1.000000e+00     -0.135988     -0.102590
# Present_Tmax      1.126554e-01 -1.359879e-01      1.000000      0.618760
# Present_Tmin      1.316462e-01 -1.025896e-01      0.618760      1.000000
# LDAPS_RHmin      -6.673316e-02 -6.948061e-02     -0.204571      0.123143
# LDAPS_RHmax      -1.669845e-01 -2.023651e-02     -0.301787     -0.015140
# LDAPS_Tmax_lapse  6.910718e-02 -1.557186e-01      0.570129      0.464151
# LDAPS_Tmin_lapse  1.047582e-01 -1.720661e-01      0.623496      0.762993
# LDAPS_WS          9.447218e-03 -5.145349e-02     -0.115984     -0.020634
# LDAPS_LH         -1.333566e-01 -1.812964e-02      0.135463     -0.009258
# LDAPS_CC1         6.918787e-03 -3.296499e-02     -0.311805      0.084447
# LDAPS_CC2         3.396039e-03 -1.570484e-02     -0.213791      0.090263
# ...

# %%
cor_hmap=df.corr()
plt.figure(figsize=(20,25))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,fmt='.1g')
plt.show()

# %%
x=df.drop('Next_Tmax',axis=1)

# %%
y=df['Next_Tmax']

# %%
x
# Out:
#       station  Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0   290          28.7          21.4    58.255688    91.116364
# 1         2.0   290          31.9          21.6    52.263397    90.604721
# 2         3.0   290          31.6          23.3    48.690479    83.973587
# 3         4.0   290          32.0          23.4    58.239788    96.483688
# 4         5.0   290          31.4          21.9    56.174095    90.155128
# ...       ...   ...           ...           ...          ...          ...
# 7747     23.0   304          23.3          17.1    26.741310    78.869858
# 7748     24.0   304          23.3          17.7    24.040634    77.294975
# 7749     25.0   304          23.2          17.4    22.933014    77.243744
# 7750     13.0     0          20.0          11.3    19.794666    58.936283
# 7751     13.0     0          37.6          29.9    98.524734   100.000153
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  \
# ...

# %%
y
# Out:
# 0       29.1
# 1       30.5
# 2       31.1
# 3       31.7
# 4       31.2
#         ...
# 7747    28.3
# 7748    28.6
# 7749    27.8
# 7750    17.4
# 7751    38.9
# Name: Next_Tmax, Length: 7752, dtype: float64

# %%
#feqature scaling using the standard scaling
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#        station      Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0    -1.664315  1.514214     -0.361326     -0.759529     0.102515
# 1    -1.525622  1.514214      0.721084     -0.676296    -0.308027
# 2    -1.386929  1.514214      0.619608      0.031188    -0.552814
# 3    -1.248236  1.514214      0.754909      0.072805     0.101426
# 4    -1.109544  1.514214      0.551957     -0.551446    -0.040098
# ...        ...       ...           ...           ...          ...
# 7747  1.386929  1.670618     -2.187892     -2.549048    -2.056591
# 7748  1.525622  1.670618     -2.187892     -2.299348    -2.241619
# 7749  1.664315  1.670618     -2.221718     -2.424198    -2.317504
# 7750  0.000000 -1.725586     -3.304127     -4.962817    -2.532517
# 7751  0.000000 -1.725586      2.649126      2.777891     2.861419
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  \
# 0        0.383078         -0.524889         -0.216663 -0.044938  0.206966
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(x.values,i)
                          for i in range(len(x.columns))]
vif["feature"] = x.columns
vif
# Out:
#           VIF           feature
# 0    1.278880           station
# 1    1.306203              Date
# 2    2.849234      Present_Tmax
# 3    3.487886      Present_Tmin
# 4    6.583412       LDAPS_RHmin
# 5    2.266562       LDAPS_RHmax
# 6    7.855193  LDAPS_Tmax_lapse
# 7    9.227135  LDAPS_Tmin_lapse
# 8    1.285813          LDAPS_WS
# 9    1.554060          LDAPS_LH
# 10   4.823314         LDAPS_CC1
# 11   5.988977         LDAPS_CC2
# 12   5.764637         LDAPS_CC3
# 13   3.383686         LDAPS_CC4
# 14   2.533640        LDAPS_PPT1
# 15   2.442973        LDAPS_PPT2
# 16   1.896521        LDAPS_PPT3
# 17   1.963731        LDAPS_PPT4
# 18   1.252241               lat
# 19   1.200369               lon
# 20   3.546565               DEM
# 21  12.996181             Slope
# 22   1.476151   Solar radiation
# 23   6.043045         Next_Tmin
# 24  12.281003            Slope

# %%
x.drop('lat',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(x.values,i)
                          for i in range(len(x.columns))]
vif["feature"] = x.columns
vif
# Out:
#           VIF           feature
# 0    1.227388           station
# 1    1.305292              Date
# 2    2.841729      Present_Tmax
# 3    3.485278      Present_Tmin
# 4    6.481529       LDAPS_RHmin
# 5    2.243432       LDAPS_RHmax
# 6    7.789103  LDAPS_Tmax_lapse
# 7    9.189631  LDAPS_Tmin_lapse
# 8    1.280504          LDAPS_WS
# 9    1.553621          LDAPS_LH
# 10   4.822158         LDAPS_CC1
# 11   5.987194         LDAPS_CC2
# 12   5.762834         LDAPS_CC3
# 13   3.383675         LDAPS_CC4
# 14   2.529940        LDAPS_PPT1
# 15   2.442890        LDAPS_PPT2
# 16   1.896041        LDAPS_PPT3
# 17   1.959554        LDAPS_PPT4
# 18   1.114208               lon
# 19   3.463123               DEM
# 20  12.995819             Slope
# 21   1.475726   Solar radiation
# 22   6.031758         Next_Tmin
# 23  12.236767            Slope

# %%
x.drop('lon',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(x.values,i)
                          for i in range(len(x.columns))]
vif["feature"] = x.columns
vif
# Out:
#           VIF           feature
# 0    1.221511           station
# 1    1.304381              Date
# 2    2.840419      Present_Tmax
# 3    3.484979      Present_Tmin
# 4    6.471556       LDAPS_RHmin
# 5    2.236269       LDAPS_RHmax
# 6    7.618406  LDAPS_Tmax_lapse
# 7    9.136136  LDAPS_Tmin_lapse
# 8    1.278548          LDAPS_WS
# 9    1.552515          LDAPS_LH
# 10   4.821054         LDAPS_CC1
# 11   5.973025         LDAPS_CC2
# 12   5.710928         LDAPS_CC3
# 13   3.380267         LDAPS_CC4
# 14   2.529745        LDAPS_PPT1
# 15   2.441914        LDAPS_PPT2
# 16   1.895895        LDAPS_PPT3
# 17   1.958950        LDAPS_PPT4
# 18   3.459261               DEM
# 19  12.769911             Slope
# 20   1.475726   Solar radiation
# 21   6.030767         Next_Tmin
# 22  11.980984            Slope

# %%
x.drop('LDAPS_Tmin_lapse',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(x.values,i)
                          for i in range(len(x.columns))]
vif["feature"] = x.columns
vif
# Out:
#           VIF           feature
# 0    1.217749           station
# 1    1.304378              Date
# 2    2.699691      Present_Tmax
# 3    3.392807      Present_Tmin
# 4    5.199850       LDAPS_RHmin
# 5    2.216279       LDAPS_RHmax
# 6    4.968493  LDAPS_Tmax_lapse
# 7    1.277280          LDAPS_WS
# 8    1.480926          LDAPS_LH
# 9    4.728633         LDAPS_CC1
# 10   5.949265         LDAPS_CC2
# 11   5.710667         LDAPS_CC3
# 12   3.379927         LDAPS_CC4
# 13   2.502912        LDAPS_PPT1
# 14   2.437103        LDAPS_PPT2
# 15   1.881189        LDAPS_PPT3
# 16   1.956162        LDAPS_PPT4
# 17   3.311406               DEM
# 18  12.618138             Slope
# 19   1.472039   Solar radiation
# 20   4.796679         Next_Tmin
# 21  11.980669            Slope

# %%
x.drop('LDAPS_Tmax_lapse',axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(x.values,i)
                          for i in range(len(x.columns))]
vif["feature"] = x.columns
vif
# Out:
#           VIF          feature
# 0    1.216906          station
# 1    1.279464             Date
# 2    2.684853     Present_Tmax
# 3    3.356370     Present_Tmin
# 4    4.121407      LDAPS_RHmin
# 5    2.216271      LDAPS_RHmax
# 6    1.231989         LDAPS_WS
# 7    1.478220         LDAPS_LH
# 8    4.714634        LDAPS_CC1
# 9    5.885053        LDAPS_CC2
# 10   5.608020        LDAPS_CC3
# 11   3.379699        LDAPS_CC4
# 12   2.479839       LDAPS_PPT1
# 13   2.437021       LDAPS_PPT2
# 14   1.870629       LDAPS_PPT3
# 15   1.941066       LDAPS_PPT4
# 16   3.253282              DEM
# 17  12.221664            Slope
# 18   1.412308  Solar radiation
# 19   3.421405        Next_Tmin
# 20  11.771911           Slope

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from  sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train.shape
# Out:
# (5426, 21)

# %%
x_test.shape
# Out:
# (2326, 21)

# %%
y_train.shape
# Out:
# (5426,)

# %%
y_test.shape
# Out:
# (2326,)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
pred_train=lr.predict(x_train)
print('R2 score:',r2_score(y_test,pred_lr))
print("r2 score on training data :",r2_score(y_train,pred_train))
print("mean absolute error:",mean_absolute_error(y_test,pred_lr))
print("mean squared error:",mean_squared_error(y_test,pred_lr))
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2 score: 0.7512878761402505
# r2 score on training data : 0.7475166358565428
# mean absolute error: 1.240945874576969
# mean squared error: 2.4433486871298844
# root mean squared error: 1.5631214562950264

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lr.predict(x_test)
pred_train=lr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print('R2 score on training data:',r2_score(y_train,pred_train))
print('mean absolute error:',mean_absolute_error(y_test,pred_lasso))
print('mean squared error:',mean_squared_error(y_test,pred_lasso))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.7512878761402505
# R2 score on training data: 0.7475166358565428
# mean absolute error: 1.240945874576969
# mean squared error: 2.4433486871298844
# root mean squared error: 1.5631214562950264

# %%
ridge=Ridge()
ridge.fit(x_train,y_train)
pred_ridge=lr.predict(x_test)
pred_train=lr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_ridge))
print('R2 score on training data:',r2_score(y_train,pred_train))
print('mean absolute error:',mean_absolute_error(y_test,pred_ridge))
print('mean squared error:',mean_squared_error(y_test,pred_ridge))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_ridge)))
# Out:
# R2 score: 0.7512878761402505
# R2 score on training data: 0.7475166358565428
# mean absolute error: 1.240945874576969
# mean squared error: 2.4433486871298844
# root mean squared error: 1.5631214562950264

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=lr.predict(x_test)
pred_train=lr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print('R2 score on training data:',r2_score(y_train,pred_train))
print('mean absolute error:',mean_absolute_error(y_test,pred_etr))
print('mean squared error:',mean_squared_error(y_test,pred_etr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.7512878761402505
# R2 score on training data: 0.7475166358565428
# mean absolute error: 1.240945874576969
# mean squared error: 2.4433486871298844
# root mean squared error: 1.5631214562950264

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbr_pred=gbr.predict(x_test)
gbr_train=gbr.predict(x_train)
print('R2 score:',r2_score(y_test,gbr_pred))
print('R2  score on training data:',r2_score(y_train,gbr_train))
print('mean absolute error:',mean_absolute_error(y_test,gbr_pred))
print('mean squared errro:',mean_squared_error(y_test,gbr_pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,gbr_pred)))
# Out:
# R2 score: 0.8353069429932407
# R2  score on training data: 0.8609334188039213
# mean absolute error: 0.9837968555303165
# mean squared errro: 1.6179451100815256
# root mean squared error: 1.2719847129905004

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(etr,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [0.63726826 0.49916093 0.5147255  0.77571915 0.63777653]
# 0.6129300737344462
# difference between R2 score and cross validation score: 13.83578024058043

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lr,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [0.71140729 0.55118668 0.60800852 0.82698607 0.6811984 ]
# 0.6757573920194597
# difference between R2 score and cross validation score: 7.553048412079077

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(gbr,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,gbr_pred)-score.mean())*100)
# Out:
# [0.65225447 0.5511397  0.52336444 0.77809828 0.60270213]
# 0.6215118058492759
# difference between R2 score and cross validation score: 21.37951371439648

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(ridge,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_ridge)-score.mean())*100)
# Out:
# [0.71147103 0.55117691 0.60803023 0.82700456 0.6811848 ]
# 0.6757735044691998
# difference between R2 score and cross validation score: 7.551437167105068

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lasso,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [0.40204382 0.33352816 0.4091605  0.28690296 0.45397745]
# 0.37712257883728373
# difference between R2 score and cross validation score: 37.41652973029667

# %%
x_a=df.drop('Next_Tmin',axis=1,inplace=True)

# %%
y_b=df['Next_Tmin']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Next_Tmin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from sklearn.model_selection import GridSearchCV

# %%
#saving the model
import joblib

# %%
joblib.dump(lr,'lrfile.obj')
# Out:
# ['lrfile.obj']

# %%
mymodel=joblib.load('lrfile.obj')
mymodel.predict(x_test)
# Out:
# array([28.66544854, 35.34040539, 27.39551543, ..., 29.53647929,
#        27.53200775, 28.55133599])

# %%
conclusion=pd.DataFrame([lr.predict(x_test)[:],y_test[:]],index=['predicted','origional'])
conclusion
# Out:
#                 0          1          2          3          4          5     \
# predicted  28.665449  35.340405  27.395515  32.744936  31.382584  29.544504
# origional  28.300000  35.900000  25.300000  35.900000  33.400000  28.600000
#
#                 6          7          8          9     ...       2316  \
# predicted  30.337791  27.461371  30.459674  28.892795  ...  27.924932
# origional  30.900000  33.600000  32.900000  25.500000  ...  34.500000
#
#                 2317      2318       2319       2320       2321       2322  \
# predicted  30.585214  30.38935  28.391655  31.727547  27.733724  28.692975
# origional  34.200000  30.80000  28.800000  34.000000  27.100000  29.700000
#
#                 2323       2324       2325
# predicted  29.536479  27.532008  28.551336
# origional  32.300000  26.800000  29.100000
#
# [2 rows x 2326 columns]

# %%
mymodel
# Out:
# LinearRegression()
