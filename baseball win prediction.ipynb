# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df1=df.rename(columns={'W':'win','R':'run score','AB':'at bat','H':'hit','2B':'two base hit','3B':'three base hit','HR':'home runs','BB':'base on ball','SO':'strikeout','SB':'stolenbase','RA':'Run average','ER':'Earned run','ERA':'Earned average run','CG':'complete game','SHO':'shouout','SV':'save','E':'Errors'})

# %%
df1
# Out:
#     win  run score  at bat   hit  two base hit  three base hit  home runs  \
# 0    95        724    5575  1497           300              42        139
# 1    83        696    5467  1349           277              44        156
# 2    81        669    5439  1395           303              29        141
# 3    76        622    5533  1381           260              27        136
# 4    74        689    5605  1515           289              49        151
# 5    93        891    5509  1480           308              17        232
# 6    87        764    5567  1397           272              19        212
# 7    81        713    5485  1370           246              20        217
# 8    80        644    5485  1383           278              32        167
# 9    78        748    5640  1495           294              33        161
# 10   88        751    5511  1419           279              32        172
# 11   86        729    5459  1363           278              26        230
# ...

# %%
df1.head(10)
# Out:
#    win  run score  at bat   hit  two base hit  three base hit  home runs  \
# 0   95        724    5575  1497           300              42        139
# 1   83        696    5467  1349           277              44        156
# 2   81        669    5439  1395           303              29        141
# 3   76        622    5533  1381           260              27        136
# 4   74        689    5605  1515           289              49        151
# 5   93        891    5509  1480           308              17        232
# 6   87        764    5567  1397           272              19        212
# 7   81        713    5485  1370           246              20        217
# 8   80        644    5485  1383           278              32        167
# 9   78        748    5640  1495           294              33        161
#
#    base on ball  strikeout  stolenbase  Run average  Earned run  \
# 0           383        973         104          641         601
# ...

# %%
df1.tail(10)
# Out:
#     win  run score  at bat   hit  two base hit  three base hit  home runs  \
# 20   90        683    5527  1351           295              17        177
# 21   83        703    5428  1363           265              13        177
# 22   71        613    5463  1420           236              40        120
# 23   67        573    5420  1361           251              18        100
# 24   63        626    5529  1374           272              37        130
# 25   92        667    5385  1346           263              26        187
# 26   84        696    5565  1486           288              39        136
# 27   79        720    5649  1494           289              48        154
# 28   74        650    5457  1324           260              36        148
# 29   68        737    5572  1479           274              49        186
#
#     base on ball  strikeout  stolenbase  Run average  Earned run  \
# 20           488       1290          51          613         557
# ...

# %%
df1.shape
# Out:
# (30, 17)

# %% [markdown]
# The datasets contain the total 30 rows and 17 columns and one is target column

# %%
df1.columns
# Out:
# Index(['win', 'run score', 'at bat', 'hit', 'two base hit', 'three base hit',
#        'home runs', 'base on ball', 'strikeout', 'stolenbase', 'Run average',
#        'Earned run', 'Earned average run', 'complete game', 'shouout', 'save',
#        'Errors'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   win                 30 non-null     int64
#  1   run score           30 non-null     int64
#  2   at bat              30 non-null     int64
#  3   hit                 30 non-null     int64
#  4   two base hit        30 non-null     int64
#  5   three base hit      30 non-null     int64
#  6   home runs           30 non-null     int64
#  7   base on ball        30 non-null     int64
#  8   strikeout           30 non-null     int64
#  9   stolenbase          30 non-null     int64
#  10  Run average         30 non-null     int64
#  11  Earned run          30 non-null     int64
#  12  Earned average run  30 non-null     float64
#  13  complete game       30 non-null     int64
#  14  shouout             30 non-null     int64
#  15  save                30 non-null     int64
# ...

# %% [markdown]
# This gives information about nullvalue,datatype and memory usages

# %%
df1.dtypes
# Out:
# win                     int64
# run score               int64
# at bat                  int64
# hit                     int64
# two base hit            int64
# three base hit          int64
# home runs               int64
# base on ball            int64
# strikeout               int64
# stolenbase              int64
# Run average             int64
# Earned run              int64
# Earned average run    float64
# complete game           int64
# shouout                 int64
# save                    int64
# Errors                  int64
# dtype: object

# %% [markdown]
# This datasets contain the integer and float type value

# %%
df1.isnull().sum()
# Out:
# win                   0
# run score             0
# at bat                0
# hit                   0
# two base hit          0
# three base hit        0
# home runs             0
# base on ball          0
# strikeout             0
# stolenbase            0
# Run average           0
# Earned run            0
# Earned average run    0
# complete game         0
# shouout               0
# save                  0
# Errors                0
# dtype: int64

# %% [markdown]
# datasets does not contain any nan value

# %%
# detecting null value through visualisation
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %%
df1.describe()
# Out:
#               win   run score       at bat          hit  two base hit  \
# count   30.000000   30.000000    30.000000    30.000000     30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333    274.733333
# std     10.453455   58.761754    70.467372    57.140923     18.095405
# min     63.000000  573.000000  5385.000000  1324.000000    236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000    262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000    275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000    288.750000
# max    100.000000  891.000000  5649.000000  1515.000000    308.000000
#
#        three base hit   home runs  base on ball   strikeout  stolenbase  \
# count       30.000000   30.000000     30.000000    30.00000   30.000000
# mean        31.300000  163.633333    469.100000  1248.20000   83.500000
# std         10.452355   31.823309     57.053725   103.75947   22.815225
# ...

# %% [markdown]
# outlier presen in all columns
# high standard deviation present in run score,at bat,baseball,strikeout ,run avarage and earned run average columns means range is too high
# mean is less than median in win,runscore,at bat,base on ball,strikeout and save column means data is skewed to leftside
# mean is greater than median in runaverage means data is skewed to rightside

# %%
df1.skew()
# Out:
# win                   0.047089
# run score             1.200786
# at bat                0.183437
# hit                   0.670254
# two base hit         -0.230650
# three base hit        0.129502
# home runs             0.516441
# base on ball          0.158498
# strikeout            -0.156065
# stolenbase            0.479893
# Run average           0.045734
# Earned run            0.058710
# Earned average run    0.053331
# complete game         0.736845
# shouout               0.565790
# save                  0.657524
# Errors                0.890132
# dtype: float64

# %%
sns.histplot(x='run score',data=df1)
# Out:
# <Axes: xlabel='run score', ylabel='Count'>

# %%
df1['run score'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['Errors'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1['home runs'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(x='hit',data=df1)
# Out:
# <Axes: xlabel='hit', ylabel='Count'>

# %%
sns.scatterplot(x='hit',y='win',data=df1)
# Out:
# <Axes: xlabel='hit', ylabel='win'>

# %%
sns.scatterplot(x='hit',y='win',data=df1)
# Out:
# <Axes: xlabel='hit', ylabel='win'>

# %%
sns.scatterplot(x='three base hit',y='win',data=df1)
# Out:
# <Axes: xlabel='three base hit', ylabel='win'>

# %%
plt.scatter(df1['three base hit'],df1['win'])

# %%
plt.scatter(df1['stolenbase'],df1['win'])

# %%
df1.plot(kind='box',subplots=True,layout=(3,6))
# Out:
# win                      Axes(0.125,0.653529;0.110714x0.226471)
# run score             Axes(0.257857,0.653529;0.110714x0.226471)
# at bat                Axes(0.390714,0.653529;0.110714x0.226471)
# hit                   Axes(0.523571,0.653529;0.110714x0.226471)
# two base hit          Axes(0.656429,0.653529;0.110714x0.226471)
# three base hit        Axes(0.789286,0.653529;0.110714x0.226471)
# home runs                Axes(0.125,0.381765;0.110714x0.226471)
# base on ball          Axes(0.257857,0.381765;0.110714x0.226471)
# strikeout             Axes(0.390714,0.381765;0.110714x0.226471)
# stolenbase            Axes(0.523571,0.381765;0.110714x0.226471)
# Run average           Axes(0.656429,0.381765;0.110714x0.226471)
# Earned run            Axes(0.789286,0.381765;0.110714x0.226471)
# Earned average run           Axes(0.125,0.11;0.110714x0.226471)
# complete game             Axes(0.257857,0.11;0.110714x0.226471)
# shouout                   Axes(0.390714,0.11;0.110714x0.226471)
# ...

# %%
#removing the skewnws
df1['run score']=np.sqrt(df1['run score'])

# %%
df1.skew()
# Out:
# win                   0.047089
# run score             0.968676
# at bat                0.183437
# hit                   0.670254
# two base hit         -0.230650
# three base hit        0.129502
# home runs             0.516441
# base on ball          0.158498
# strikeout            -0.156065
# stolenbase            0.479893
# Run average           0.045734
# Earned run            0.058710
# Earned average run    0.053331
# complete game         0.736845
# shouout               0.565790
# save                  0.657524
# Errors                0.890132
# dtype: float64

# %%
df1['complete game'].plot.box()
# Out:
# <Axes: >

# %%
df1['Errors'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# outlier present in errors column

# %%
df1['hit'].plot.box()
# Out:
# <Axes: >

# %%
df1['Run average'].plot.box()
# Out:
# <Axes: >

# %%
df1.corr()
# Out:
#                          win  run score    at bat       hit  two base hit  \
# win                 1.000000   0.430751 -0.087947  0.037612      0.427797
# run score           0.430751   1.000000  0.319464  0.482856      0.560084
# at bat             -0.087947   0.319464  1.000000  0.739122      0.453370
# hit                 0.037612   0.482856  0.739122  1.000000      0.566847
# two base hit        0.427797   0.560084  0.453370  0.566847      1.000000
# three base hit     -0.251118  -0.070072  0.435422  0.478694      0.220490
# home runs           0.307407   0.671283 -0.066983 -0.090855      0.056292
# base on ball        0.484342   0.402452 -0.136414 -0.118281      0.302700
# strikeout           0.111850  -0.054726 -0.106022 -0.398830     -0.150752
# stolenbase         -0.157234   0.081367  0.372618  0.413444      0.195027
# Run average        -0.812952  -0.041623  0.316010  0.224324     -0.218160
# Earned run         -0.809435  -0.041245  0.309686  0.252489     -0.235531
# ...

# %%
corr_hmap=df1.corr()
plt.figure(figsize=(10,12))
sns.heatmap(df1.corr(),annot=True,linewidths=0.1,fmt='.1g')
plt.show()

# %%
# seprating the feature and label
x=df1.drop('win',axis=1)

# %%
y=df1['win']

# %%
x
# Out:
#     run score  at bat   hit  two base hit  three base hit  home runs  \
# 0         724    5575  1497           300              42        139
# 1         696    5467  1349           277              44        156
# 2         669    5439  1395           303              29        141
# 3         622    5533  1381           260              27        136
# 4         689    5605  1515           289              49        151
# 5         891    5509  1480           308              17        232
# 6         764    5567  1397           272              19        212
# 7         713    5485  1370           246              20        217
# 8         644    5485  1383           278              32        167
# 9         748    5640  1495           294              33        161
# 10        751    5511  1419           279              32        172
# 11        729    5459  1363           278              26        230
# 12        661    5417  1331           243              21        176
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: win, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#     run score    at bat       hit  two base hit  three base hit  home runs  \
# 0    0.619078  0.847731  1.663685      1.420173        1.041193  -0.787299
# 1    0.134432 -0.711094 -0.970681      0.127403        1.235809  -0.243967
# 2   -0.332906 -1.115233 -0.151891      1.588795       -0.223808  -0.723377
# 3   -1.146419  0.241522 -0.401088     -0.828122       -0.418423  -0.883181
# 4    0.013270  1.280738  1.984081      0.801892        1.722347  -0.403770
# 5    3.509647 -0.104884  1.361089      1.869832       -1.391501   2.185047
# 6    1.311430  0.732263 -0.116292     -0.153633       -1.196885   1.545833
# 7    0.428681 -0.451289 -0.596886     -1.615025       -1.099578   1.705636
# 8   -0.765626 -0.451289 -0.365489      0.183611        0.068115   0.107601
# 9    1.034489  1.785913  1.628086      1.082929        0.165423  -0.084163
# 10   1.086415 -0.076017  0.275303      0.239818        0.068115   0.267405
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
vif=pd.DataFrame()
vif["VIF.values"] = [variance_inflation_factor(x.values, i) 
                          for i in range(len(x.columns))] 
vif['features']=x.columns
vif
# Out:
#      VIF.values            features
# 0     11.522370           run score
# 1     13.311532              at bat
# 2     10.070668                 hit
# 3      4.019297        two base hit
# 4      3.294146      three base hit
# 5     10.079902           home runs
# 6      3.806098        base on ball
# 7      2.652401           strikeout
# 8      2.102684          stolenbase
# 9    191.839155         Run average
# 10  1680.387145          Earned run
# 11  1222.722240  Earned average run
# 12     3.059904       complete game
# 13     3.654331             shouout
# 14     5.798850                save
# 15     2.186219              Errors

# %%
x.drop('Earned average run',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
vif=pd.DataFrame()
vif["VIF.values"] = [variance_inflation_factor(x.values, i) 
                          for i in range(len(x.columns))] 
vif['features']=x.columns
vif
# Out:
#     VIF.values        features
# 0    11.375311       run score
# 1     4.464580          at bat
# 2     9.162137             hit
# 3     3.896371    two base hit
# 4     3.254143  three base hit
# 5     9.741435       home runs
# 6     3.804402    base on ball
# 7     2.652395       strikeout
# 8     1.895026      stolenbase
# 9   171.126556     Run average
# 10  163.993427      Earned run
# 11    2.814675   complete game
# 12    3.480272         shouout
# 13    3.740063            save
# 14    2.142827          Errors

# %%
x.drop('Earned run',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor 
vif=pd.DataFrame()
vif["VIF.values"] = [variance_inflation_factor(x.values, i) 
                          for i in range(len(x.columns))] 
vif['features']=x.columns
vif
# Out:
#     VIF.values        features
# 0    10.791320       run score
# 1     4.369242          at bat
# 2     8.568511             hit
# 3     3.667399    two base hit
# 4     2.998994  three base hit
# 5     7.586684       home runs
# 6     3.541589    base on ball
# 7     2.181428       strikeout
# 8     1.844092      stolenbase
# 9     5.068366     Run average
# 10    2.723889   complete game
# 11    3.383050         shouout
# 12    3.110481            save
# 13    2.072298          Errors

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from  sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=43)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=43)
#
# NameError: name 'train_test_split' is not defined

# %%
x_train.shape
# Out:
# (21, 14)

# %%
x_test.shape
# Out:
# (9, 14)

# %%
y_train.shape
# Out:
# (21,)

# %%
y_test.shape
# Out:
# (9,)

# %%
y_test.shape
# Out:
# (9,)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
pred_train=lr.predict(x_train)
print('R2 score:',r2_score(y_test,pred_lr))
print("r2 score on training data :",r2_score(y_train,pred_train))
print("mean absolute error:",mean_absolute_error(y_test,pred_lr))
print("mean squared error:",mean_squared_error(y_test,pred_lr))
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2 score: 0.8325979684843446
# r2 score on training data : 0.9578664352021916
# mean absolute error: 3.407662234083953
# mean squared error: 22.543473577441592
# root mean squared error: 4.747996796275413

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_lr,y=y_test)
plt.plot(pred_lr,pred_lr)
plt.xlabel('actual',fontsize=14)
plt.ylabel('predicted',fontsize=14)
plt.title('linear regression',fontsize=14)
# Out:
# Text(0.5, 1.0, 'linear regression')

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
lasso=Lasso(alpha=.0001)
lasso.fit(x_train,y_train)
pred_lasso=lr.predict(x_test)
pred_train=lr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print('R2 score on training data:',r2_score(y_train,pred_train))
print('mean absolute error:',mean_absolute_error(y_test,pred_lasso))
print('mean squared error:',mean_squared_error(y_test,pred_lasso))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.8325979684843446
# R2 score on training data: 0.9578664352021916
# mean absolute error: 3.407662234083953
# mean squared error: 22.543473577441592
# root mean squared error: 4.747996796275413

# %%
ridge=Ridge(alpha=0.0001)
ridge.fit(x_train,y_train)
pred_ridge=lr.predict(x_test)
pred_train=lr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_ridge))
print('R2 score on training data:',r2_score(y_train,pred_train))
print('mean absolute error:',mean_absolute_error(y_test,pred_ridge))
print('mean squared error:',mean_squared_error(y_test,pred_ridge))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_ridge)))
# Out:
# R2 score: 0.8325979684843446
# R2 score on training data: 0.9578664352021916
# mean absolute error: 3.407662234083953
# mean squared error: 22.543473577441592
# root mean squared error: 4.747996796275413

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
gbr_pred=gbr.predict(x_test)
gbr_train=gbr.predict(x_train)
print('R2 score:',r2_score(y_test,gbr_pred))
print('R2  score on training data:',r2_score(y_train,gbr_train))
print('mean absolute error:',mean_absolute_error(y_test,gbr_pred))
print('mean squared errro:',mean_squared_error(y_test,gbr_pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,gbr_pred)))
# Out:
# R2 score: 0.6344416181710308
# R2  score on training data: 0.9999999438815997
# mean absolute error: 6.4012802580175
# mean squared errro: 49.228528752967854
# root mean squared error: 7.016304494031588

# %%
knn= KNeighborsClassifier()
knn.fit(x_train,y_train)
knn_pred=gbr.predict(x_test)
knn_train=knn.predict(x_train)
print('R2 score:',r2_score(y_test,knn_pred))
print('R2  score on training data:',r2_score(y_train,knn_train))
print('mean absolute error:',mean_absolute_error(y_test,knn_pred))
print('mean squared errro:',mean_squared_error(y_test,knn_pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,knn_pred)))
# Out:
# R2 score: 0.6344416181710308
# R2  score on training data: -0.42124524251000284
# mean absolute error: 6.4012802580175
# mean squared errro: 49.228528752967854
# root mean squared error: 7.016304494031588

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
rf_pred=gbr.predict(x_test)
knn_train=knn.predict(x_train)
print('R2 score:',r2_score(y_test,rf_pred))
print('mean absolute error:',mean_absolute_error(y_test,rf_pred))
print('mean squared errro:',mean_squared_error(y_test,rf_pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,rf_pred)))
# Out:
# R2 score: 0.6344416181710308
# mean absolute error: 6.4012802580175
# mean squared errro: 49.228528752967854
# root mean squared error: 7.016304494031588

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
etr_pred=etr.predict(x_test)
etr_train=etr.predict(x_train)
print('R2 score:',r2_score(y_test,etr_pred))
print('R2  score on training data:',r2_score(y_train,etr_train))
print('mean absolute error:',mean_absolute_error(y_test,etr_pred))
print('mean squared errro:',mean_squared_error(y_test,etr_pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,etr_pred)))
# Out:
# R2 score: 0.7360186468646863
# R2  score on training data: 1.0
# mean absolute error: 5.21777777777778
# mean squared errro: 35.54948888888891
# root mean squared error: 5.962339212833241

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lr,x,y,cv=5)
print(score)
print(score.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [ 0.53061073 -0.73766653  0.56029287  0.61308645  0.73554523]
# 0.3403737484572939
# difference between R2 score and cross validation score: 49.22242200270507

# %%
from sklearn.model_selection import cross_val_score
score2=cross_val_score(lasso,x,y,cv=5)
print(score2)
print(score2.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [ 0.53072726 -0.73842938  0.56032597  0.61340315  0.73573334]
# 0.34035206847819627
# difference between R2 score and cross validation score: 49.22242200270507

# %%
from sklearn.model_selection import cross_val_score
score3=cross_val_score(ridge,x,y,cv=5)
print(score3)
print(score3.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [ 0.53065023 -0.7377465   0.56028808  0.61311012  0.73557556]
# 0.34037549732604144
# difference between R2 score and cross validation score: 49.22242200270507

# %%
from sklearn.model_selection import cross_val_score
score4=cross_val_score(gbr,x,y,cv=5)
print(score4)
prin  t(score4.mean())
print('difference between R2 score and cross validation score:',(r2_score(y_test,pred_lr)-score.mean())*100)
# Out:
# [ 0.13717228 -8.90358822  0.22419457  0.32890661  0.56483013]
# -1.5296969253011243
# difference between R2 score and cross validation score: 49.22242200270507

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1.0,0.05,.4,2],'fit_intercept':[True,False],
     'solver':['auto','svd','choleskey','lsqr','say','sag','saga','ibfgs'],
     'positive':[False,True],
     'random_state':[1,4,10,20]
      }
gscv= GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'choleskey', 'lsqr', 'say',
#                                     'sag', 'saga', 'ibfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 1,
#  'solver': 'saga'}

# %%
model=Ridge(alpha=2,fit_intercept=True,positive=False,random_state=1,solver='saga')

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('R2 score:',r2_score(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('mean squared errro:',mean_squared_error(y_test,pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.8083736911950041
# mean absolute error: 3.9046859924737873
# mean squared errro: 25.805676252406105
# root mean squared error: 5.079928764501142

# %%
import pickle
filename="baseball.pkl"
pickle.dump(model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('baseball.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.8083736911950041

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['predicted','origional'])

# %%
conclusion
# Out:
#                    0           1          2          3          4         5  \
# predicted  82.002119  100.869393  70.499125  90.730944  91.878517  80.78908
# origional  79.000000  100.000000  67.000000  97.000000  80.000000  78.00000
#
#                    6          7          8
# predicted  71.276163  63.296288  81.185241
# origional  74.000000  63.000000  85.000000
